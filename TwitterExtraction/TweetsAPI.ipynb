# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ## **Library**
# ___

# %%
import json, os
from enum import Enum, auto
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

## time library
import time
from time import perf_counter

## requests library
import requests
from requests_oauthlib import OAuth1
from requests.exceptions import HTTPError, ConnectionError
from requests import Timeout

# %% [markdown]
# ## **Access Recent Tweets with Twitter API `v2`**
# ___

# %%
## Collection of twitter endpoints
TWITTER_ENDPT = {
    'recent_search' : "https://api.twitter.com/2/tweets/search/recent",
}

## Set up user-agent
USER_AGENT = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36"

## Insert bearer token for Twitter API V2.0
BEARER_TOKEN = "<Your bearer token here>"

## Specify time window
TIME_WINDOW = 900

## Set query parameters here

### query parameters for Twitter API V2.0
QUERY_PARAMS = {
    # 'query' : '(Sony OR #Sony) (wf-1000xm4 OR ear buds) lang:en -is:retweet',
    'query' : '(Sony OR #Sony) (wf-1000xm4 OR ear buds)',
    'max_results' : 30,
    'tweet.fields' : 'author_id,public_metrics,created_at,attachments,context_annotations',
    'expansions' : 'author_id', 
}

## Specify max request in time window
MAX_REQ = 450

## Rate limit in time per request
RATE_LIMIT = TIME_WINDOW // MAX_REQ + 0.5

## Total data points requrred
N_DATAPTS = 100

## Maximum empty response limit
MAX_EMPTY = 2

## Maximum request exception limit
MAX_ERROR = 2

# %%
## set up authentication header for request
def bearer_oauth(r):
  r.headers["Authorization"] = f"Bearer {BEARER_TOKEN}"
  r.headers["User-Agent"] = USER_AGENT
  return r

## make single request to Twitter endpoint
def connect_to_endpoint(url, params, timeout=180, print_error=True):
  try:
    response = requests.get(url, auth=bearer_oauth, params=params, timeout=timeout)
    response.raise_for_status()
    return response.json(), True
  except HTTPError as http_err:
    if print_error:
      print(f"HTTP error occurred: {http_err}")
    return f"HTTP error occurred: {http_err}", False
  except ConnectionError as conn_err:
    if print_error:
      print(f"Connection error occurred: {conn_err}")
    return f"Connection error occurred: {conn_err}", False
  except Timeout as time_err:
    if print_error:
      print(f"Timeout error occurred after {timeout} seconds: {time_err}")
    return f"Timeout error occurred after {timeout} seconds: {time_err}", False
  except Exception as err:
    if print_error:
      print(f"Other error occurred: {err}")
    return f"Other error occurred: {err}", False

# %%
count = 0 # track total result count
max_error = 0 # track maximum failed requests from the last successful request
max_empty = 0 # track maximum empty response from the last non-empty response
newest_id = 0 # track the newest id at current response
oldest_id = 0 # track the oldest id at current response
i_count = 0 # track the count at current response
js_objs = []  # store all the response json objects
stats = []  # track connection statuses
i = 0 # track current iteration
now = 0 # track current time before request
old = 0 # track time at last request

print("Start digging tweets...")
while count <= N_DATAPTS:
  i += 1

  now = perf_counter()
  if (now - old) <= RATE_LIMIT:
    time.sleep(RATE_LIMIT - (now - old))
  resp, stat = connect_to_endpoint(TWITTER_ENDPT['recent_search'], QUERY_PARAMS)
  old = perf_counter()

  if stat:
    if "data" in resp:
      js_objs.append(resp)
      stats.append(f"{i}: Connection successful.")

      # update newest, oldest id, query parameters and count
      newest_id = resp['meta']['newest_id']
      oldest_id = resp['meta']['oldest_id']
      QUERY_PARAMS['until_id'] = oldest_id
      count += resp['meta']['result_count']

      # update other trackers
      max_error = 0
      max_empty = 0

      # continue with next iteration
      continue
    else:
      stats.append(f"{i}: Empty response returned.")
      max_empty += 1
      if max_empty >= MAX_EMPTY:
        break
      else:
        continue
  else:
    stats.append(f"{i}: {resp}")
    max_error += 1
    if max_error >= MAX_ERROR:
      break
    else:
      continue

# remove until_id key in the original query parameters
try:
  del QUERY_PARAMS['until_id']
except:
  pass

## serialize all data points 
print("Serializing data points...")
data_objs = [data for resp in js_objs for data in resp['data']]
print("Done.")
# Out:
# Start digging tweets...
# Serializing data points...
# Done.

# %%
stats
# Out:
# ['1: Connection successful.',
#  '2: Connection successful.',
#  '3: Connection successful.',
#  '4: Connection successful.']

# %%
## Destination file
ROOT_DIR = "/content/gdrive/MyDrive/Twitter"
DST_FILE = os.path.join(ROOT_DIR, 'test.json')

## save all data objects to dst file
with open(DST_FILE, 'w') as dst:
  json.dump(data_objs, dst)

# %%
## get texts from all data
texts = [data['text'] for data in data_objs]

# %%
## clean each text
def clean_tweet(tw):
  tw = re.sub(r'@[A-Za-z0-9]+', '', tw) # remove @mentions
  tw = re.sub(r'#', '', tw) # remove # in hashtags
  tw = re.sub(r'RT[\s]+', '', tw) # remove occasional RT in retweets
  tw = re.sub(r'https?:\/\/\S+', '', tw)  # remove the hyper link
  return tw

cleaned_tw = [clean_tweet(tw) for tw in texts]

# %%
cleaned_tw
# Out:
# [' こんにちは。ソニーサポートです。WF-1000XM4をご購入いただき、ありがとうございます。褒めてくださって嬉しいです✨\n基本操作や便利な機能を下記Webページでご紹介しておりますので、よろしければご活用ください🎵\n■使いこなしガイド→',
#  ' こんにちは。ソニーサポートです。WF-1000XM4をご購入いただき、ありがとうございます。音楽をたくさん楽しんでください。\n基本操作や便利な機能を下記Webページでご紹介しておりますので、よろしければご活用ください🎵\n■使いこなしガイド→',
#  ' sonyのwf-1000xm4最高だよ😚',
#  '_2402 こんにちは。ソニーサポートです。WF-1000XM4をご購入いただき、ありがとうございます。ノイキャン性能を褒めていただきうれしいです。\n基本操作や便利な機能を下記Webページでご紹介しておりますので、よろしければご活用ください🎵\n■使いこなしガイド→',
#  ': ワイヤレス イヤホン SONY ソニー WF-1000XM4 BM ブラック Bluetooth ノイズキャンセリング ノイキャン iPhone13 ipad mini Android switch 通話 マイク付き 防水 IPX4 ハイレゾ…',
#  '_Aorus: 重要な音質に関しては正直WF-1000XM4は言われてるほど良いとは言えないと思う、ここに関してはGalaxy Buds Proが1つ2つ上を行っている。自分がAKGユーザーというのもあるが(とはいえスピーカーやヘッドホンはSONYも使用…',
#  '"Les nouveaux Sony WF-1000XM4 sont d’ores et déjà victimes des promotions"  AnglohaTech Anglohasys',
#  '_Aorus: 重要な音質に関しては正直WF-1000XM4は言われてるほど良いとは言えないと思う、ここに関してはGalaxy Buds Proが1つ2つ上を行っている。自分がAKGユーザーというのもあるが(とはいえスピーカーやヘッドホンはSONYも使用…',
#  '_Ch_n: 100RTいったら、SONYのwf-1000xm4買う\n\nちなみに値段は定価3万超え。 ',
#  '_Ch_n: 100RTいったら、SONYのwf-1000xm4買う\n\nちなみに値段は定価3万超え。 ',
#  '100RTいったら、SONYのwf-1000xm4買う\n\nちなみに値段は定価3万超え。 ',
#  '_kawagoe: 📢大人気フルワイヤレスイヤホン\n\nSONY：フルワイヤレスイヤホン\n 『WF‐1000XM4』\n\n現在ホワイト・ブラック共に在庫ございます( *´艸｀)\n 税込26,350円✨\n\n展示もございますのでご視聴いただけます！！\n\n是非この…',
#  '_ipride: 前々から欲しかったSONYのwf-1000xm4 買っちゃった🤟\nSONYだからしょうがないんだけどDolby Atmos対応して欲しいよな🥺\nAppleユーザーだけどイヤホンは高校生の頃からSONYだったな ',
#  '_Aorus: 重要な音質に関しては正直WF-1000XM4は言われてるほど良いとは言えないと思う、ここに関してはGalaxy Buds Proが1つ2つ上を行っている。自分がAKGユーザーというのもあるが(とはいえスピーカーやヘッドホンはSONYも使用…',
#  "Liked on YouTube: Sony WF-1000XM4 (vs. Apple AirPods Pro) - an AUDIOPHILE's perspective ",
#  'ソニー(SONY) WF-1000XM4 : 完全ワイヤレス/Amazon Alexa搭載/Bluetooth/LDAC対応/ハイレゾ相当 /高精度通話品質/IPX4防滴性能/ 2021年モデル / マイク付き    より \n\n参考価格:￥33,000 \n価格:￥23,955 \nOFF:￥9,045 (27%)\n\n内臓マイク気になります',
#  '_kawagoe: 📢大人気フルワイヤレスイヤホン\n\nSONY：フルワイヤレスイヤホン\n 『WF‐1000XM4』\n\n現在ホワイト・ブラック共に在庫ございます( *´艸｀)\n 税込26,350円✨\n\n展示もございますのでご視聴いただけます！！\n\n是非この…',
#  '_shojo: sony wf-1000xm4めためたいいな…………… 外音取り込みがほぼノーイヤホンと一緒くらい聴こえるので人と話す時もイヤホンつけっぱなしで行ける………',
#  'SONY製品でしっかりリークされて発表会の時に「リーク通りだ」ってなった記憶があるのはWF-1000XM4と１IIIくらいだった気がする\nそれ以外に何かあったっけ？',
#  '_kawagoe: 📢大人気フルワイヤレスイヤホン\n\nSONY：フルワイヤレスイヤホン\n 『WF‐1000XM4』\n\n現在ホワイト・ブラック共に在庫ございます( *´艸｀)\n 税込26,350円✨\n\n展示もございますのでご視聴いただけます！！\n\n是非この…',
#  'Sony WF-1000XM4が安いのか……\nポイントとか使えば……',
#  '_earphone: ＜貴重なインタビュー動画！＞\n\nSONY \n完全ワイヤレスイヤホン \nノイズキャンセリング\n\n話題の完全ワイヤレスイヤホン SONY WF-1000XM4 開発者インタビュー！\n▽動画はこちら▽\n',
#  'sony wf-1000xm4めためたいいな…………… 外音取り込みがほぼノーイヤホンと一緒くらい聴こえるので人と話す時もイヤホンつけっぱなしで行ける………',
#  '📢大人気フルワイヤレスイヤホン\n\nSONY：フルワイヤレスイヤホン\n 『WF‐1000XM4』\n\n現在ホワイト・ブラック共に在庫ございます( *´艸｀)\n 税込26,350円✨\n\n展示もございますのでご視聴いただけます！！\n\n是非この機会にソフマップ川越店ご利用くださいませ！！\n\n川越 埼玉 ',
#  ': ワイヤレス イヤホン SONY ソニー WF-1000XM4 BM ブラック Bluetooth ノイズキャンセリング ノイキャン iPhone13 ipad mini Android switch 通話 マイク付き 防水 IPX4 ハイレゾ…',
#  'SONY\u3000\u3000高価買取中♪\u3000\n\n大量大歓迎✨✨✨✨！！\nSONY WF-1000XM4 ブラック*24000\nSONY WF-1000XM4 シルバー*24000',
#  'ワイヤレス イヤホン SONY ソニー WF-1000XM4 BM ブラック Bluetooth ノイズキャンセリング ノイキャン iPhone13 ipad mini Android switch 通話 マイク付き 防水 IPX4 ハイレゾ対応 【送料無料】【代引き不可】【長期保証加入可】 [楽天]  RakutenBookmark',
#  '【日版】Sony WF-1000XM4 無線降噪耳機 網店特價\xa0＄2099 ',
#  '_earphone: ＜貴重なインタビュー動画！＞\n\nSONY \n完全ワイヤレスイヤホン \nノイズキャンセリング\n\n話題の完全ワイヤレスイヤホン SONY WF-1000XM4 開発者インタビュー！\n▽動画はこちら▽\n',
#  '価格.com - SONY WF-1000XM4 価格比較  より\n\n値段下がりすぎててびっくりw',
#  '_earphone: ＜貴重なインタビュー動画！＞\n\nSONY \n完全ワイヤレスイヤホン \nノイズキャンセリング\n\n話題の完全ワイヤレスイヤホン SONY WF-1000XM4 開発者インタビュー！\n▽動画はこちら▽\n',
#  '_earphone: ＜貴重なインタビュー動画！＞\n\nSONY \n完全ワイヤレスイヤホン \nノイズキャンセリング\n\n話題の完全ワイヤレスイヤホン SONY WF-1000XM4 開発者インタビュー！\n▽動画はこちら▽\n',
#  '＜貴重なインタビュー動画！＞\n\nSONY \n完全ワイヤレスイヤホン \nノイズキャンセリング\n\n話題の完全ワイヤレスイヤホン SONY WF-1000XM4 開発者インタビュー！\n▽動画はこちら▽\n',
#  '_liker_desk: SONY WF-1000XM4購入🙌\n武蔵野レーベルのカバーも同時にポチっておきました。\nワイヤレス充電器をどうしようか🤔\n\nwf1000xm4 ',
#  ' _moss これですね。\nSONYのWF-1000XM4、発売日に買って翌日紛失。\n修理費15000円。 ',
#  'ふむ。24,000円切りはAmazonの気の迷いじゃないのね。ノジマやeイヤホンでも同じになってる。即ポチしたい気持ちはありつつ、本当にこんな無難な選択でいいのか？という気も。/\nSONY WF-1000XM4 価格比較 - 価格.com ',
#  'SONY WF-1000XM4\u3000なんと価格が！！！\n ',
#  '_jpn MDR-CD900STじゃん 嘘でもWF-1000XM4付けないと',
#  'Kindle Paperwhiteが5000円引き\n32GB\n\n8GB\n\n\n24000円切り、ソニー(SONY)  WF-1000XM4 ブラック \n\n\nアマギフチャージ\n\n\nAmazon',
#  'ソニー(SONY)ワイヤレスノイズキャンセリングイヤホン WF-1000XM4\n : 完全ワイヤレス/Amazon Alexa搭載/Bluetooth/LDAC対応/ハイレゾ相当 最大8時間連続再生/高精度通話品質/IPX4防滴性能/ ワイヤレス充電対応/2021年モデル / マイク付き \n\n',
#  'ソニー(SONY) の ソニー ワイヤレスノイズキャンセリングイヤホン WF-1000XM4 : Amazon Alexa搭載/Bluetooth/LDAC対応/ハイレゾ相当/高精度通話品質/IPX4防滴性能/ ワイヤレス充電対応/2021年モデル / マイク付き 360 Reality Audio認定モデル を Amazon でチェック！  ',
#  '【大幅値下げ】 SONY（ソニー） ワイヤレスノイズキャンセリングイヤホン WF-1000XM4 送料込23955円 ',
#  '_earphone: 【禁断の比較！？】\n完全ワイヤレス 3機種比較！\nSONY WF-1000XM4\nApple AirPods Pro\nBOSE QC Earbuds\n\n▽レビュー動画はこちら▽\n',
#  '_earphone: 【禁断の比較！？】\n完全ワイヤレス 3機種比較！\nSONY WF-1000XM4\nApple AirPods Pro\nBOSE QC Earbuds\n\n▽レビュー動画はこちら▽\n',
#  '_earphone: 【禁断の比較！？】\n完全ワイヤレス 3機種比較！\nSONY WF-1000XM4\nApple AirPods Pro\nBOSE QC Earbuds\n\n▽レビュー動画はこちら▽\n',
#  '【禁断の比較！？】\n完全ワイヤレス 3機種比較！\nSONY WF-1000XM4\nApple AirPods Pro\nBOSE QC Earbuds\n\n▽レビュー動画はこちら▽\n',
#  'SONY WF-1000XM4購入🙌\n武蔵野レーベルのカバーも同時にポチっておきました。\nワイヤレス充電器をどうしようか🤔\n\nwf1000xm4 ',
#  'AirPodsとSONYのWF-1000XM4どっちが良いか迷う',
#  'SONY\u3000ソニー \nワイヤレスノイズキャンセリングイヤホン \nWF-1000XM4\n\n⬇️Amazon\n',
#  ': 26,350円 ソニー SONY WF-1000XM4 S [完全ワイヤレスイヤホン Bluetooth/ノイズキャンセリング対応 DSEE Extreme搭載 プラチナシルバー] ',
#  '26,350円 ソニー SONY WF-1000XM4 S [完全ワイヤレスイヤホン Bluetooth/ノイズキャンセリング対応 DSEE Extreme搭載 プラチナシルバー] ',
#  '「まとめ買いクーポン発行中」【即日発送】【新品】SONY ソニー フルワイヤレスイヤホン ブラック WF-1000XM4 BM【新品】SONY ソニー フルワイヤレスイヤホン ブラック WF-1000...\n\n',
#  'SONY フルワイヤレスイヤホン WF-1000XM4 ブラックメーカー:SONY 発売日:2021年6月25日【ご購入前にご確認ください】 メーカー様で企画されているイベント・キャンペーンへの対象で...\n\n',
#  'おはよぉ☁\n\nそういえばワイヤレスイヤンホホを買いました！\nオススメして貰ったの色々試聴したりして考えた挙句SONYのWF-1000xm4にしました。\n\nまぁ、音楽関係で使ってる周辺機器も携帯もSONYなので根っからの信者なのです←(〇〇万は貢いでる)\n\n今日も1日🍞 ',
#  '世の中には、優れたBluetoothヘッドフォンがいくつも出回っています。\nAirPods Pro、Sony WF-1000XM4、Jabra Elite Active 75tはイヤフォン市場を席巻しており、Sony WH-1000XM4やBose Noise Cancelling Headphones 700はオーバーイヤータイプの中でも特に優れています。\n ',
#  'SONYのWF-1000XM4使ってる人いる？\nインプレが聞きたい。',
#  '未視聴だから偉そうな事は言えないけど個人的にはPanasonicのEAH-AZ40をええタイミングで買えるか静観してる…SONY WF-C500はカタチが上位機種のWF-1000XM4と似ているからと勘違いした評価してるおかしな人間が多いが、音質的にはJBL WAVE100 TWS当たりと同等ランクだと思っておかないと。',
#  'ソニー SONY ノイズキャンセリング機能搭載完全ワイヤレス Bluetoothイヤホン 1000Xシリーズワイヤレスノイズキャンセリングイヤホン WF-1000XM4送料無料(沖縄、離島除く)メーカ...\n\n',
#  'ソニー(SONY) の ソニー ワイヤレスノイズキャンセリングイヤホン WF-1000XM4 : 完全ワイヤレス/Amazon Alexa搭載/Bluetooth/LDAC対応/ハイレゾ相当 最大8時間連続再生/高精度通話品質/IPX4防滴性能/ ワイヤレス充電対応/2021年モデル / マイク付き 360 Reality Audio認定モデル プラチナシルバー',
#  ' Sony WF-1000XM4',
#  '_king: ✅SONY WF-1000XM4 単品が27%OFF🔥23955円💰\n\n✔️ホワイト\n\n\n✔️ブラック\n\n\n入荷時期未定だけど安過ぎる🤣',
#  ': 10/12  07:30現在\nSONY WF-1000XM4 単品が27%OFFの23955円！\n\n今でも人気なワイヤレスイヤホンがこれだけ値下げって熱い🔥\n\n',
#  'SONY ハイレゾワイヤレスイヤホン\n\n',
#  '_king: ✅SONY WF-1000XM4 単品が27%OFF🔥23955円💰\n\n✔️ホワイト\n\n\n✔️ブラック\n\n\n入荷時期未定だけど安過ぎる🤣',
#  'SONYのワイヤレスイヤホン WF-1000XM4が\n\n27%OFFの23955円！！！\n\nホワイト\n\n\nブラック\n\n\n入荷時期未定だけど欲しかった人にはチャンス✨\n(2021.10.12 08:00)',
#  ': 10/12  07:30現在\nSONY WF-1000XM4 単品が27%OFFの23955円！\n\n今でも人気なワイヤレスイヤホンがこれだけ値下げって熱い🔥\n\n',
#  '_king: ✅SONY WF-1000XM4 単品が27%OFF🔥23955円💰\n\n✔️ホワイト\n\n\n✔️ブラック\n\n\n入荷時期未定だけど安過ぎる🤣',
#  'デジタルの日が終わったのに安い！🥳\n\n❇️SONY WF-1000XM4\n\n27%OFF✨\n\u3000👉¥23,955\n\n入荷時期は未定ですが、購入いけます🙆\u200d♂️(7:45)\n\n⚪️プラチナシルバー\n\n\n⚫️ブラック\n\n\n🔻現金チャージで最大2.5%還元\n',
#  '',
#  '_king: ✅SONY WF-1000XM4 単品が27%OFF🔥23955円💰\n\n✔️ホワイト\n\n\n✔️ブラック\n\n\n入荷時期未定だけど安過ぎる🤣',
#  ': 10/12  07:30現在\nSONY WF-1000XM4 単品が27%OFFの23955円！\n\n今でも人気なワイヤレスイヤホンがこれだけ値下げって熱い🔥\n\n',
#  '_king: ✅SONY WF-1000XM4 単品が27%OFF🔥23955円💰\n\n✔️ホワイト\n\n\n✔️ブラック\n\n\n入荷時期未定だけど安過ぎる🤣',
#  ': 10/12  07:30現在\nSONY WF-1000XM4 単品が27%OFFの23955円！\n\n今でも人気なワイヤレスイヤホンがこれだけ値下げって熱い🔥\n\n',
#  '_king: ✅SONY WF-1000XM4 単品が27%OFF🔥23955円💰\n\n✔️ホワイト\n\n\n✔️ブラック\n\n\n入荷時期未定だけど安過ぎる🤣',
#  '10/12  07:30現在\nSONY WF-1000XM4 単品が27%OFFの23955円！\n\n今でも人気なワイヤレスイヤホンがこれだけ値下げって熱い🔥\n\n',
#  '✅SONY WF-1000XM4 単品が27%OFF🔥23955円💰\n\n✔️ホワイト\n\n\n✔️ブラック\n\n\n入荷時期未定だけど安過ぎる🤣',
#  'SONYノイズキャンセリングイヤホンWF-1000XM4用シリコンケース販売中！\n\nノイズキャンセリング WF1000XM4 Sony Yahooショッピング',
#  ': ▼商品詳細\nワイヤレスノイズキャンセリングステレオヘッドセット\u3000WF-1000XM4\n\n\n▼「好プレー投票キャンペーン」の応募要領、注意事項は下記URLをチェックしてください。\n',
#  '【 楽天 】 ランキング 【TV・オーディオ・カメラ】7位\nワイヤレス イヤホン SONY ソニー WF-1000XM4 BM ブラック Bluetooth ノイズキャンセリング ノイキャン …\n価格 28270円\n\n↓こちらから↓\n  ',
#  'Sony WF-1000XM4 True Wireless Noise-Canceling Earbuds both in BLACK &amp; WHITE \n\nOrder online for delivery or visit our NYC store at 29 West 46th Street, between 5th and 6th avenue.\n\nEmail at sales.com, live chat, or call (212) 354-6424 for help!',
#  '_Gold @________urmyg Sony WF-1000XM4',
#  'Edifier NeoBuds Pro:\n有線には劣るがSony WF-1000XM4と比較して音質は遥かに上。\nBA+DDの2Wayドライバーの威力。\nLDAC音質優先接続による音切れは同程度。\n室内で寝フォンとしてしか使わないのでこれでいい。\n使わなくなったSony WF-1000XM4は売却処分の予定だがここ数日でかなり値崩れしている。 ',
#  ' Hi, I don’t mean to be rude but you aren’t answering my question:\nIf the battery in a pair of WF-1000XM4 has lost its capacity, can the battery *in* an earpiece be replaced (read: the earpiece be repaired) or will Sony merely replace the entire earpiece and trash the old one?',
#  ": Une baisse de prix pour l'une des meilleures références sur le marché 🔥 BonPlan 👇 ",
#  'Les nouveaux Sony WF-1000XM4 sont d’ores et déjà victimes des promotions : ',
#  'Les nouveaux Sony WF-1000XM4 sont d’ores et déjà victimes des promotions\n',
#  'Les nouveaux Sony WF-1000XM4 sont d’ores et déjà victimes des promotions &gt;&gt; Frandroid &lt;&lt; ',
#  "Une baisse de prix pour l'une des meilleures références sur le marché 🔥 BonPlan 👇 ",
#  'Les nouveaux Sony WF-1000XM4 sont d’ores et déjà victimes des\xa0promotions ',
#  'FrAndroid : Les nouveaux Sony WF-1000XM4 sont d’ores et déjà victimes des promotions Audio Bonsplans Bonsplansaudio marques Produits sony SonyWF1000XM4 ',
#  'SONYのWF-1000XM4の使いやすさに慣れてしまってからSennheiserのMomentum truewireless2を放置してしまってる。\nワイヤレスイヤホンでコイツを超える使い勝手の良いヤツないっすか?\nしばらくコイツが耳のお供にならざるを得ないと思ってる🎵',
#  '重要な音質に関しては正直WF-1000XM4は言われてるほど良いとは言えないと思う、ここに関してはGalaxy Buds Proが1つ2つ上を行っている。自分がAKGユーザーというのもあるが(とはいえスピーカーやヘッドホンはSONYも使用している)Galaxy Buds ProはAKG監修でとても素晴らしい音質だ。',
#  ': ▼商品詳細\nワイヤレスノイズキャンセリングステレオヘッドセット\u3000WF-1000XM4\n\n\n▼「好プレー投票キャンペーン」の応募要領、注意事項は下記URLをチェックしてください。\n',
#  '_Ikegami: 【動画更新!】\n今更ですがブルートゥースイヤホンを買い替えました^^;\n発売から数ヶ月経ってのレビュー動画です笑\n\n【Sony】WF-1000XM3とWF-1000XM4を比べてみた結果【完全ワイヤレスイヤホン】\n',
#  ': ▼商品詳細\nワイヤレスノイズキャンセリングステレオヘッドセット\u3000WF-1000XM4\n\n\n▼「好プレー投票キャンペーン」の応募要領、注意事項は下記URLをチェックしてください。\n',
#  'Sony WF-1000XM4 ワイヤレス Noise Cancelling イヤホン, Fully ワイヤレス, Amazon Alexa, Bluetooth, LDAC Compatible, High Resolution Equivalent, Up to 8 Hours of Continuous Playback, High Precision Call Quality, IPX4 Splashproof Performance, ワイヤレス Charging Support, 2021 Model,',
#  ': ▼商品詳細\nワイヤレスノイズキャンセリングステレオヘッドセット\u3000WF-1000XM4\n\n\n▼「好プレー投票キャンペーン」の応募要領、注意事項は下記URLをチェックしてください。\n',
#  'NowBrowsing: 価格.com - SONY WF-1000XM4 (B) [ブラック] 価格推移グラフ ',
#  'ソニー SONY ワイヤレスノイズキャンセリングステレオヘッドセット WF-1000XM4 BM ブラック【商品解説】いい音には、静寂が要る。業界最高クラスノイキャンに、ハイレゾ完全ワイヤレス■業界最高クラスのノイズキャ',
#  'うちの最高のTWSダブルエース\nSONY WF-1000XM4 × SAMSUNG Galaxy Buds Pro ',
#  ' Naja, zumindest ist das eine sehr gewagte Aussage. \n\nMal schauen was andere Tests so sagen. \n\nDenke doch das Faultier wird die auch noch testen. Auf seine Meinung ist eigentlich immer Verlass. \n\nDamir findet die Sony WF-1000XM4\neher mehr schlecht als gut, für den Preis.',
#  ' \n\nChina Gadgets meint die neuen Soundcore Liberty 3 Pro sind besser als Sonys WF-1000XM4. \n\nDas klingt für dich als Sony Fan sicher wie Gotteslästerung 😃',
#  'JBL TOUR PRO+\n\nのテスト視聴終わりましたが、2021年で一番気に入ったTWSですね\n\nSONYのWF-1000XM4より全然好きです\n\nCLUB PRO+ とはベツモノですね。新しい振動板が良い仕事してます\n\nTOUR PRO+ は、CLUB PRO+の後継機ではなく、JBLのフラッグシップTWSですね。まるで味付けが違います',
#  'ランキング:3位 「オーディオ機器・ヘッドホン」 (23:11)\n\nSONY イヤホン【ワイヤレス(左右分離)/Bluetooth/リモコン・マイク対応/ノイ...\n\n価格:26,350円🔥\n\n',
#  '前々から欲しかったSONYのwf-1000xm4 買っちゃった🤟\nSONYだからしょうがないんだけどDolby Atmos対応して欲しいよな🥺\nAppleユーザーだけどイヤホンは高校生の頃からSONYだったな ',
#  ': ▼商品詳細\nワイヤレスノイズキャンセリングステレオヘッドセット\u3000WF-1000XM4\n\n\n▼「好プレー投票キャンペーン」の応募要領、注意事項は下記URLをチェックしてください。\n',
#  '_nacker: 【eイヤ秋葉原店 中古】\nSONY WF-1000XM4\nあの大人気ワイヤレスイヤホンがお求めやすくなりました😃😃\n\nランクA アクセサリ全てあり\n各色《23,900円》\n\n各店舗在庫多数ございます💫💫\nぜひご検討下さい🙏🙏🙏\n⬇WEBサ…',
#  '【P5倍 本日限定】 ＼送料無料／ ソニー sony wf1000xm4 wf-1000xm4 ケース カバー シリコン 2021最新 カラビナ付き ワイヤレス充電対応 4色 保護 キズ防止 落下防止 耐衝撃性 紛失防止 収納 かわいい 在庫発送あり \n\n',
#  'ある程度の自己紹介！\nイヤホンヘッドホン各愛機\nSONY WF -1000XM4\nSONY WH -1000XM4\nASMR用イヤホンとして\nfinal VR3000 for gaming\n好きなエナドリは\nモンスター\u3000パイプラインパンチ\nZONE INFINITY GATE\n最近よく使ってる文具は\nパイロット\u3000s30です！以上！',
#  'ソニー(SONY) の ソニー ワイヤレスノイズキャンセリングイヤホン WF-1000XM4 : 完全ワイヤレス/Amazon Alexa搭載/Bluetooth/LDAC対応/ハイレゾ相当 最大8時間連続再生/高精度通話品質/IPX4防滴性能/ ワイヤレス充電対応/2021年モデル / マイク付き 360 Reality Audio認定モデル ブラック',
#  '\nSONYワイヤレスイヤホンのwf-1000xm4が23,955円で売っているのだが...\nしかもAmazon内にあるSONY公式！？\n...入荷未定だがこれは買うしかない...',
#  'ワイヤレス イヤホン SONY ソニー WF-1000XM4 BM ブラック Bluetooth ノイズキャンセリング ノイキャン iPhone13 ipad mini Android switch 通話 マイク付き 防水 IPX4 ハイレゾ対応 【送料無料】【代引き不可】【長期保証加入可】 [楽天]  rakuafl ',
#  'え、ちょっ、これは最新型のSONYのノイキャンイヤホンでは…\n\nSONY ノイズキャンセリング イヤホン ノイキャン WF1000XM4 特価 激安特価',
#  '_nacker: 【eイヤ秋葉原店 中古】\nSONY WF-1000XM4\nあの大人気ワイヤレスイヤホンがお求めやすくなりました😃😃\n\nランクA アクセサリ全てあり\n各色《23,900円》\n\n各店舗在庫多数ございます💫💫\nぜひご検討下さい🙏🙏🙏\n⬇WEBサ…',
#  'sony wf-1000xm4ほちい',
#  'SONYのwf-1000xm4値下げか？？この価格になるんならマジで最強！ただ今の部材高騰時期にキツそうやけど。 ',
#  '_Ikegami: 【動画更新!】\n今更ですがブルートゥースイヤホンを買い替えました^^;\n発売から数ヶ月経ってのレビュー動画です笑\n\n【Sony】WF-1000XM3とWF-1000XM4を比べてみた結果【完全ワイヤレスイヤホン】\n',
#  ': ▼商品詳細\nワイヤレスノイズキャンセリングステレオヘッドセット\u3000WF-1000XM4\n\n\n▼「好プレー投票キャンペーン」の応募要領、注意事項は下記URLをチェックしてください。\n',
#  '_nacker: 【eイヤ秋葉原店 中古】\nSONY WF-1000XM4\nあの大人気ワイヤレスイヤホンがお求めやすくなりました😃😃\n\nランクA アクセサリ全てあり\n各色《23,900円》\n\n各店舗在庫多数ございます💫💫\nぜひご検討下さい🙏🙏🙏\n⬇WEBサ…',
#  'ソニー(SONY) の ソニー ワイヤレスノイズキャンセリングイヤホン WF-1000XM4\n\nなんか急に6000円も安くなってるけどどういうこと？？？\n\n より']

# %% [markdown]
# ## **Exploring Twitter API `v1.1` to get `full archive search` or `30-day search`**
# ___
#
# > 30-day tweet search:
#   * 250 requests / month
#   * 25K tweets / month
#
# > Full archive search:
#   * 50 requests / month
#   * 5K tweets /month
#
# > View [this page](https://developer.twitter.com/en/docs/twitter-api/premium/search-api/guides/operators) for the list of query operators. Most useful operators such as `is:retweet` is only available for premium paid subscribers.

# %%
## Specify authorization credentials (user key, secret, access token, access token secret)
AUTH_PARAMS = {
    'client_key' : '<Your user key here>',
    'client_secret' : '<Your user key secret here>',
    'resource_owner_key' : '<Your access token here>',
    'resource_owner_secret' : '<Your access token secret here>',
}


## Create OAuth1 authentication
auth = OAuth1(**AUTH_PARAMS)

## Specify development environment name
FULL_ENV = 'fulltest'
THIRTY_ENV = '30test'

## Define service endpoints
SERVICES = {
    'full_search' : f'https://api.twitter.com/1.1/tweets/search/fullarchive/{FULL_ENV}.json',
    '30_search' : f'https://api.twitter.com/1.1/tweets/search/30day/{THIRTY_ENV}.json'
}

## Total data returned from single request
DATA_PER_REQ = 100

## Define search parameters here for full archival search. 
# Start and end dates are necessary
FULL_QUERY_PARAMS = {
    'query' : "(Logitech OR #Logitech) (G915)",
    'maxResults' : str(DATA_PER_REQ),
    'fromDate' : '202101010000',
    'toDate' : '202110010000',
}

## Define search parameters here 30-day tweets search
# Start and end dates cannot be more than 30 days apart
THIRTY_QUERY_PARAMS = {
    'query' : "(Logitech OR #Logitech) (G915) review lang:en",
    'maxResults' : str(DATA_PER_REQ),
}

## Specify total data required
DATA_TOTAL = 200

## Specify maximum number of failed request to be tolerated
MAX_ERROR = 1

## Specify rate limit here (Request per second)
RPS = 10

# %%
## make single request to Twitter endpoint
def connect_to_endpoint(url, auth, params, timeout=180, print_error=True):
  try:
    response = requests.get(url, auth=auth, params=params, timeout=timeout)
    response.raise_for_status()
    return response.json(), True
  except HTTPError as http_err:
    if print_error:
      print(f"HTTP error occurred: {http_err}")
    return f"HTTP error occurred: {http_err}", False
  except ConnectionError as conn_err:
    if print_error:
      print(f"Connection error occurred: {conn_err}")
    return f"Connection error occurred: {conn_err}", False
  except Timeout as time_err:
    if print_error:
      print(f"Timeout error occurred after {timeout} seconds: {time_err}")
    return f"Timeout error occurred after {timeout} seconds: {time_err}", False
  except Exception as err:
    if print_error:
      print(f"Other error occurred: {err}")
    return f"Other error occurred: {err}", False

# %%
resp_objs = []  # store response from every request
status = [] # store status of every request
count = 0 # track number of data points collected
i = 0 # keep track of iteration
next_page = True  # keep track if next page exists
n_error = 0 # keep track of number of failed request from last successful request
start_time = 0  # keep track of the start time of every rate limit cycle
end_time = 0  # keep track of the end time of every rate limit cycle

print("Start digging tweets...")
while count < DATA_TOTAL and next_page:
  # record end time of every rate limit cycle
  if i%RPS == 0:
    end_time = perf_counter()
    if (end_time - start_time) < 1:
      time.sleep(1.5 - (end_time - start_time))

  i += 1
  # record start time of every rate limit cycle
  if i%RPS == 1:
    start_time = perf_counter()

  # make API request
  resp, stat = connect_to_endpoint(SERVICES['30_search'],
                                   auth=auth,
                                   params=THIRTY_QUERY_PARAMS)
  
  
    
  if stat:
    resp_objs.append(resp['results'])
    
    # indicate no next page available if 'next' is not in payload
    if 'next' not in resp:
      next_page = False
    else:
      THIRTY_QUERY_PARAMS['next'] = resp_objs['next']
    
    # update count
    count += len(resp['results'])

    # update n_error
    n_error = 0

    # update status
    status.append(f"{i}: Request successful.")

    # continue to next loop
    continue
  else:
    # update n_error
    n_error += 1

    # update status
    status.append(f"{i}: {resp}")
  
  if n_error > MAX_ERROR:
    break

# delete next key in query
try:
  del THIRTY_QUERY_PARAMS['next']
except:
  pass

# serialize the data objects
print("Serializing objects")
all_data = [obj for resp in resp_objs for obj in resp]
print("Done.")
# Out:
# Start digging tweets...
# Serializing objects
# Done.

# %%
# get all texts
all_texts = [obj['text'] for obj in all_data]

# %%
all_texts
# Out:
# ['On Blog of Dad:  Logitech G915 LIGHTSPEED With GL Tactile Switches Review https://t.co/Tfen7dfCtM',
#  'On Blog of Dad:  Logitech G915 LIGHTSPEED With GL Tactile Switches Review https://t.co/Tfen7dfCtM',
#  'On Blog of Dad:  Logitech G915 LIGHTSPEED With GL Tactile Switches Review https://t.co/Tfen7dfCtM',
#  'On Blog of Dad:  Logitech G915 LIGHTSPEED With GL Tactile Switches Review https://t.co/Tfen7dfCtM',
#  'On Blog of Dad:  Logitech G915 LIGHTSPEED With GL Tactile Switches Review https://t.co/Tfen7dfCtM',
#  'On Blog of Dad:  Logitech G915 LIGHTSPEED With GL Tactile Switches Review https://t.co/Tfen7dfCtM',
#  'On Blog of Dad:  Logitech G915 LIGHTSPEED With GL Tactile Switches Review https://t.co/Tfen7dfCtM',
#  'On Blog of Dad:  Logitech G915 LIGHTSPEED With GL Tactile Switches Review https://t.co/Tfen7dfCtM']
