# %%
import sklearn
import nltk
import re 
import json
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from sklearn import metrics
from sklearn.feature_selection import SelectKBest
from sklearn.feature_extraction.text import TfidfVectorizer #as vectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
from sklearn.metrics import precision_score, recall_score,f1_score
from sklearn.linear_model import LogisticRegression

##########################################################################3
##prepare dataset
from os import getcwd, chdir
import pandas as pd
import pickle as pk
fpath = getcwd()
print (fpath)
# Change your path here
chdir(fpath)
# Out:
# C:\Users\user\Documents\GitHub\ISS_PLP_Project\SentimentModels\Training\Shopee_Aspect

# %%
lines = []
with open('absa_textcat.jsonl', 'r') as f:
    for line in f:
        lines.append(json.loads(line))

# %%
lines[:1]
# Out:
# [{'text': 'CNY.Nicely fitting on me',
#   '_input_hash': 1564655371,
#   '_task_hash': 1845939222,
#   'options': [{'id': 'POSITIVE', 'text': 'POSITIVE'},
#    {'id': 'NEGATIVE', 'text': 'NEGATIVE'}],
#   '_session_id': None,
#   '_view_id': 'choice',
#   'config': {'choice_style': 'multiple'},
#   'accept': ['POSITIVE'],
#   'answer': 'accept',
#   '_timestamp': 1636024288}]

# %%
Y=[]
X=[]
for l in lines:
    X.append(l['text'])
    if l['accept']==['POSITIVE']:
        Y.append(1)
    else:
        Y.append(-1)

# %%
len(X)
# Out:
# 1358

# %%
X_train=X[:int(len(Y)*0.8)]
X_test=X[int(len(Y)*0.8):]
Y_train=Y[:int(len(Y)*0.8)]
Y_test=Y[int(len(Y)*0.8):]

# %%
X_train
# Out:
# ['CNY.Nicely fitting on me',
#  'I like the material',
#  'Perfect fit',
#  'nice material',
#  'Must buy 1 size bigger',
#  'nice color',
#  'Comfort and cooling in Singapore weather',
#  'Thank you seller for the fast delivery',
#  'Quality is so gd',
#  'Received in good condition',
#  'very thin , lightweight and stretchy material',
#  'quite tight',
#  'Items well received',
#  'Looks comfy',
#  'would be better if it is entirely cotton',
#  'delivery on time',
#  'Received less than a month',
#  'buttons is slightly apart',
#  'very very very fast delivery',
#  'Fast Delivery',
#  'size a little bit to small',
#  'texture is little hard',
#  'Item received in good order',
#  'Light soft cotton material',
#  'Received fasssssssssssssssssssssst',
#  'soft quality',
#  'shirt is a bit big and shorts a bit small',
#  'received in good condition',
#  'Order came fast',
#  'quality is good',
#  'Delivery was fast item came well packed',
#  'feels good and is comfortable',
#  'Thickness is not too thick',
#  'Good quality',
#  'comfortable',
#  'Fast delivery',
#  'material is different',
#  'a bit on the hot side',
#  'look quite nice',
#  'do not fit well',
#  'simply too small',
#  'Well received',
#  'good quality',
#  'Item came as described',
#  'the size for the pants is too tight',
#  'the shirt is big enough',
#  'is comfortable',
#  'quality , but seems good to me',
#  'size too small',
#  'quality not bad',
#  'price is ok',
#  'Fits nicely',
#  'quite a few loose strands',
#  'Item received in good condition',
#  'Still feel cheap',
#  'Size is accurate',
#  'material is quite soft',
#  'fits just how I like it',
#  'material is thin and cooling',
#  'good price',
#  'cheap',
#  'still v tight for me',
#  'love the quality',
#  'Love the colour',
#  'Soft and cool material',
#  'Love the design',
#  'great deal',
#  'really comfortable',
#  'Very nice piece of jacket',
#  'worth the price',
#  'item received in good condition',
#  'Items received in good condition',
#  'okay for price paid',
#  'fits me just right',
#  'soft and comfortable',
#  'Came well packaged and relatively quickly',
#  'Awesome deal',
#  'fast delivery',
#  'Material is very thin',
#  'very soft',
#  'Quite prompt delivery',
#  'Quality is acceptable',
#  'Nice mint colour',
#  'Good fit',
#  'quality feels good too',
#  'Soft And comfy',
#  'Nice fitting',
#  'material is pretty hot',
#  'normal quality',
#  'size is bit too small',
#  'a bit tight for me',
#  'Nice design',
#  'Came in good condition',
#  'Very cheap',
#  'very good quality',
#  'seem fit for me',
#  'Cheapest I can find',
#  'quite thin',
#  'abit rough',
#  'overall is comfortable',
#  'very fast delivery',
#  'received it in a very good condition',
#  'good condition',
#  'Delivery was pretty fast',
#  'Delivery was kinda ok',
#  'super effective for sweating',
#  'easy to rip off',
#  'Material thinner than expected',
#  'reasonable quality',
#  'True to size',
#  'very comfortable',
#  'love the material',
#  'Design looks quite nice',
#  'Good material',
#  'Good and soft',
#  'very cheap',
#  'fit well',
#  'Nice and cool material',
#  'Delivery fast',
#  'Product material was good',
#  'received quite fast',
#  'quality of the purple one is thicker but looks firmer',
#  'there were a few loose threads',
#  'pretty good condition',
#  'Size up if you want a looser pyjamas',
#  'material was so much better',
#  'Value for money',
#  'pretty fast delivery',
#  'Really have to buy 2 size bigger than your usual size to fit',
#  'Gd material',
#  'it does nt look green at all lol looks more brown ish',
#  'does nt fit petite ppl',
#  'Material is good and smooth',
#  'Order received with good condition and quite fast',
#  'value for $ $',
#  'material are very cooling',
#  'timely delivery',
#  'Delivery is fast',
#  'shorter than i expected',
#  'delivery came in nicely',
#  'thin & soft material',
#  'thin and nice',
#  'Very fast delivery',
#  'Material very soft',
#  'arrived well packed',
#  'fit quite snugly',
#  'length is shorter than expect',
#  'Very cute design',
#  'very comfy',
#  'super fast delivery',
#  'Ordered 3 items but only received 2',
#  'item is cheap',
#  'colour is better',
#  'Received it in 4 days ! !',
#  'was big for me',
#  'quality of the material is nice',
#  'fits me perfectly',
#  'live the material',
#  'super comfortable',
#  'does not fit',
#  'fabric itself is nice',
#  'Took so long to receive the item',
#  'Product size is different from the actual size',
#  'Item received quite fast',
#  'Comfortable material',
#  "Delivery did n't take too long to arrive",
#  'Material is soft and comfortable',
#  'fits well on me',
#  'Speedy delivery',
#  'Sizing just nice',
#  'comfortable to wear',
#  'Good price',
#  'Item is nicely packed',
#  'Colour seems not bad',
#  'material is considered comfortable',
#  'Its XL size tho',
#  'Delivery was fast',
#  'Colour is nice',
#  'material is okay',
#  'looks abit weird mayb we could have gotten a smaller size',
#  'Very lightweight and comfortable',
#  'nice colour',
#  'good fit',
#  'material is quite thick',
#  'A bit shorter than I expected',
#  'size is ok overall',
#  'Material is perfect for sg weather',
#  "length is shown in picture of 93 cm ,   it came and it was n't",
#  'received as described',
#  'nice outfit',
#  'Received item as per description',
#  'price is very cheap',
#  'Material is not bad',
#  'Size is a bit smaller than usual',
#  'Price is good',
#  'betu comfortable',
#  'Received item as expected',
#  'came really quickly',
#  'material was meh',
#  'The crop top is pretty high though , like i ordered a large but when i raised my hands , my ahems were exposed',
#  'Comfortable and cooling',
#  'Need to take 1 size bigger',
#  "the colour is n't as claimed",
#  'Material is light',
#  'Fits nice at ankle',
#  'Quite comfortable',
#  'good . quality',
#  'size is right',
#  'receive in good condition',
#  'very soft and very nice',
#  'Very nice pieces',
#  'quality is fine for me',
#  'Nice quality',
#  'Item well received',
#  'size all good',
#  'Very comfortable',
#  'comfy',
#  'fitting',
#  'good prices',
#  'Decent quality',
#  'they look great',
#  'they will last a long time',
#  'looks ok',
#  'Material was ok',
#  'thicker than items in pic',
#  'nice design',
#  'reasonable price',
#  'Super duper comfortable',
#  'last quite long',
#  'great for the price',
#  'Quality is good',
#  'fits me very well',
#  'soft and comfy',
#  'sleeves were too short for me',
#  'Quality is ok',
#  'embroidery abit flaying',
#  'delivery abit slow',
#  'Cutting is slightly small',
#  'Well received with thanks',
#  'quality is acceptable',
#  'received already my purchase in good condition',
#  'Super fast delivery',
#  'nice to touch',
#  'quality ok',
#  'Slightly tight',
#  'Received the item in good condition',
#  'material is comfy and nice',
#  'amazing quality',
#  'Measurements pretty true to chart',
#  'Zipper abit not that smooth',
#  'lousy quality',
#  'sizing is way off',
#  'Looks good',
#  'strap toooooo short',
#  'Slow delivery',
#  'received in very good condition',
#  'Quite comfy',
#  'well packaged',
#  'Shipping time is quite fast',
#  'its fit me',
#  'Unique design makes you pretty and stylish in summer',
#  'is comfortable to wear',
#  'Worth my money',
#  'material looks and feels good',
#  'Item delivered as described',
#  'strong smell',
#  'A few creases',
#  'material quite thin',
#  'Comfortable to wear',
#  'cheaper compared to outside',
#  'item well packed',
#  'Material is very comfortable to wear',
#  'Price very cheap',
#  'Material was good',
#  'looked nice',
#  'delivery was quite fast',
#  'Very sexy and looks gorgeous',
#  'delivery very slow',
#  'Material very soft and comfy',
#  'material very good not to thick',
#  'it ’s so comfortable',
#  'overal looks nice',
#  'Came in like two days',
#  'it fits nicely',
#  'it ’s too small',
#  'has been well received',
#  'Delivery took awhile',
#  'Good padding comfort',
#  'Items delivered in time frame',
#  'would be better to have S size',
#  "it 's very cute",
#  'dam comfy material',
#  'a low price',
#  'took some time to come',
#  'really nice pants',
#  'Order received in good condition',
#  'Really really comfy',
#  'Colours are pretty',
#  'would recommend even for sleeping',
#  'arrived earlier than expected',
#  'Material is kinda scratchy',
#  'sexy',
#  'decent for the price',
#  'received the goods in satisfactory condition',
#  'Sleeve not as long as what it looks like',
#  'Got a hole on the t - shirt',
#  'they assist to despatch shipment very fast',
#  'very good material',
#  'Quite satisfied with how it looks',
#  'quality wise is good',
#  'material is thin but quality looks quite good',
#  'Worth it for money',
#  'Quality not bad',
#  'length is great',
#  'Good product quality',
#  'So worth it',
#  'fit like a gloves',
#  'Items came within time frame',
#  'the cutting runs small',
#  'Comfortable',
#  'looks good',
#  'Item came in good condition',
#  'delivery is very fast',
#  'soft material',
#  'price relatively cheap',
#  'quality is pretty good',
#  'Material is soft',
#  'Took a long time to arrive',
#  'Super comfy',
#  'nice texture',
#  'Material feels comfortable',
#  'Poor product quality',
#  'For the price of it its alright',
#  'the material is thick',
#  'Delivery super fast',
#  'Great quality',
#  'fast shipping',
#  'it is worth my money',
#  'Quick hand delivery',
#  'Cute',
#  'very affordable',
#  'love the cute cut',
#  'Size and material wise were good',
#  'very very cute',
#  'love the colour',
#  'really soft',
#  'good quality and thick material',
#  'definitely worth my money',
#  'Received it well packed',
#  'Sizing is perfect',
#  'Quality not bad',
#  'length is great',
#  'Good product quality',
#  'So worth it',
#  'fit like a gloves',
#  'Items came within time frame',
#  'the cutting runs small',
#  'Comfortable',
#  'looks good',
#  'Item came in good condition',
#  'delivery is very fast',
#  'soft material',
#  'price relatively cheap',
#  'Material very cooling and not warm',
#  'sizing runs small',
#  'Delivery time was okay',
#  'the price is cheap',
#  'quality is also ai n’t bad',
#  'Delivery took about a week',
#  'arrived in good condition',
#  'Both sizes fit my current bras',
#  'Is very nice design',
#  'Very good material',
#  'Good deal',
#  'is worth of money',
#  'it is a bit tight   for me',
#  'delivery was quick',
#  'quality was relatively good',
#  'Delivery took awhile to come',
#  'Shipping quite fast',
#  'Very disappointed with the meterial',
#  'Poor quality',
#  "it 's very small",
#  'Delivery quite okay',
#  'Worth the price',
#  'Received item in good condition',
#  'Order received with good conditions',
#  'quite decent quality',
#  'shipping was rather quick',
#  'boxes are all dented after receiving',
#  'seem like not brand new',
#  'got one smell',
#  'Received very promptly and in good condition',
#  'Good quality material',
#  'Size is ok',
#  'Received well after 2 weeks',
#  'Colors very pretty',
#  'Material on the thin side',
#  'for price ok lah',
#  'Item received well pack',
#  'Color very lovely',
#  'size is just nice',
#  'Soft material',
#  'affordable',
#  'Material is quite thick',
#  'Received goods in good',
#  'Delivery is good',
#  'Received after waiting for 2 weeks',
#  'very fitting',
#  'Delivery took ard 2 weeks',
#  'Quality and design ok',
#  'Size looks abit small on me',
#  'Material is thin',
#  'Items came in a wrecked box',
#  'Slightly longer , extends to half my quads',
#  'Quick delivery',
#  'very value for money',
#  'fit is exceptional',
#  'Really good material',
#  'Nice blue colour',
#  'size slightly small',
#  'Very bad quality',
#  'Very thin',
#  'Not worth to buy',
#  'Order rec’d in good condition',
#  'there is a little stain on the burberry t - shirt',
#  'good quality material',
#  'Quality was smooth',
#  'pajamas are comfortable',
#  'the designs are so cute',
#  'feels   very good',
#  'fits well',
#  'Material is nice and comfortable',
#  'Quality is reasonable',
#  'not exp',
#  'Quality and material feels good',
#  'material very light but super warm',
#  'it is REALLY CUTE',
#  'definitely a steal',
#  'GOOD MATERIAL',
#  'Received with good condition',
#  'Zip not so smooth',
#  'good quality tops',
#  'L size is a bit smaller',
#  'Material is cooling and nice',
#  'Pants pf good quality',
#  "Ca n't complain as it is $ 15",
#  'Material still okay',
#  'Delivery still okay',
#  'Price good',
#  "it 's ferry comfortable",
#  'Sizing to small for an XL',
#  'look nice',
#  'very long',
#  'Size accurate',
#  'Item received promptly',
#  'Delivery abit slow',
#  'OK for the price paid',
#  'chest area abit small',
#  'Quality not very good',
#  'very oversized',
#  'material quite thin and itchy type',
#  'arrived way sooner than expected',
#  'size need to chose 2 size bigger',
#  'Material are soft and comfortable',
#  'a bit too fitting for me',
#  'For very skinny people',
#  'Only 1 universal size',
#  'The size is bigger',
#  'Fast delivwey',
#  'The dog is sooo cute',
#  'the pant is slightly longer',
#  'padding and strap is comfortable',
#  'Nice for the price',
#  'quality is soft and comfy',
#  'reasonable delivery time',
#  'L size is just nice',
#  'Recieved the item in good condition',
#  'material is soft and comfy',
#  'happy with the quality',
#  'Items received as described and in good condition',
#  'inner tights was wrongly sewn',
#  'Love the material',
#  'A bit loose for me',
#  'Good quality cotton',
#  'Package delivered well',
#  'Size is appropriate',
#  'item received on time',
#  'Product received promptly',
#  'Material is very soft and comfy',
#  'Delivery was linger than usual',
#  'Its a nice piece',
#  'The size fit me totally',
#  '.The date I received also fast',
#  'i wash today and colour drop a bit',
#  'quality is no good',
#  'not worth it',
#  'got the item within 4 days',
#  'Fit perfectly',
#  'Liked the material',
#  "Did n't expect to receive the products so soon",
#  'Fits okay',
#  'material is good for the price i paid',
#  'delivery was rather fast',
#  'Delivery take some time',
#  'material is nice',
#  'not as pretty as the photo',
#  'Both sizing is slightly different',
#  'delivery quite fast',
#  'not bad material',
#  'a bit smaller cutting',
#  'quality okay okay',
#  'became a bit light after 1 wash',
#  'material is very cooling',
#  'it ’s so cheap',
#  'one of the seams is broken',
#  'pants fits well',
#  'Order received with thanks',
#  'Very soft material',
#  'nice Material',
#  'size as described',
#  'size just nice',
#  'Received within 2 weeks',
#  'materials do nt feel comfortable',
#  'Items look like received in good condition',
#  'Cheap and good',
#  'Size wise , need to order 2 size bigger than your original size',
#  'quality is good  ',
#  'Worth buying  ',
#  'Well received in a good condition',
#  'Item received quite a reasonable time',
#  'always cute',
#  'affordable products',
#  'size is good',
#  'very good condition and prompt delivery',
#  'Quality is good for price',
#  'Sizing is a comfortable fit for 168 cm 45KG',
#  'just nice for my height',
#  'A bit uncomfortable',
#  'too big size',
#  'Received my order in good condition',
#  'the size is tight therefore I buy one size bigger',
#  'size is a bit loose and there are no size in between',
#  'price is worth it',
#  'true to size for me',
#  'Singlets come with chemical smell',
#  'Grey singlets feel prickly when worn',
#  'Nice and cute item',
#  'Some loose threads',
#  'Good workmanship and fit',
#  'Lace is soft and smooth',
#  'alright for the price',
#  'Nice and comfy …',
#  'Beautifully knitted',
#  'cheaper than retail',
#  'true to size',
#  'the sleeve is abit too long for me',
#  'nevertheless the material is so good',
#  'cheaper than retail',
#  'true to size',
#  'the sleeve is abit too long for me',
#  'nevertheless the material is so good',
#  'Items arrived nicely packed',
#  'Material feels soft',
#  'looks cute',
#  'nice designs',
#  'Color is on point',
#  'material and cutting is not bad',
#  'Fits me nicely',
#  'Items arrived nicely packed',
#  'Material feels soft',
#  'looks cute',
#  'nice designs',
#  'Color is on point',
#  'material and cutting is not bad',
#  'Fits me nicely',
#  'Gooooood material',
#  'price is cheap',
#  'Arrived in good condition',
#  'Like the design',
#  'comfortable material',
#  'material is very comfy',
#  'Ca nt ask for too much for the price',
#  'So fast delivery',
#  'Gooooood material',
#  'price is cheap',
#  'Arrived in good condition',
#  'Like the design',
#  'comfortable material',
#  'material is very comfy',
#  'Material also good',
#  'Always comfortable to wear',
#  'it fit my son',
#  'soft and comfortable material',
#  'Material was very soft and comfortable',
#  'Received very promptly',
#  'It was very big and large',
#  'quality wise seems ok',
#  'took some time to reach',
#  'Item received in 3 days & in good condition',
#  'Ca nt ask for too much for the price',
#  'So fast delivery',
#  'Material also good',
#  'Always comfortable to wear',
#  'it fit my son',
#  'soft and comfortable material',
#  'Material was very soft and comfortable',
#  'Received very promptly',
#  'It was very big and large',
#  'quality wise seems ok',
#  'clothes true to size',
#  'Quality is not bad',
#  'Fits really well',
#  'Material is good',
#  'Cheap',
#  'Material feels really nice',
#  'fit perfectly',
#  'This seller sell cheaper',
#  'Is not thick good for sg weather',
#  'Material seems good',
#  'Material quite thin',
#  'quality looks okay',
#  'Took quite long to deliver by normal mail',
#  'Material is thick enough to keep you warm',
#  "they are n't cheap",
#  'took some time to reach',
#  'Cutting is good',
#  'Item received in 3 days & in good condition',
#  'the deliver is fast',
#  'material feel good',
#  'size is smaller than expected',
#  'super good quality',
#  'fits exactly',
#  'very smooth and comfortable',
#  'Nice and comfortable',
#  'this material not hot',
#  'clothes true to size',
#  'Quality is not bad',
#  'Fits really well',
#  'Material is good',
#  'Cheap',
#  'super good quality',
#  'fits exactly',
#  'worth the money',
#  'Quality is worth the price',
#  'Item delivered in good condition',
#  'Material is really light and smooth',
#  'value for money',
#  'Size L fits nicely',
#  'very soft and silky',
#  'very smooth and comfortable',
#  'Nice and comfortable',
#  'comfortable to wear under skirts',
#  "it 's a bit tight",
#  'Thin material',
#  'quality is ok for the price paid',
#  'Worth the buy',
#  'delivery time is ok',
#  'material is very think.i do nt think is good for working.will',
#  'Item was well received',
#  'this material not hot',
#  'worth the money',
#  'Quality is worth the price',
#  'Item delivered in good condition',
#  'material is not as thick as original',
#  'Material was not bad',
#  'it fit well just nice',
#  'Material is really light and smooth',
#  'value for money',
#  'Delivery was very fast',
#  'arrived earlier than the expected date',
#  'so soft , cooling and seamless',
#  'Thank you so much for arranging delivery promptly',
#  'Material is still nice',
#  'Material is quite good',
#  'Received product as pictured',
#  'material is not as thick as original',
#  'Material was not bad',
#  'it fit well just nice',
#  'Delivery was very fast',
#  'arrived earlier than the expected date',
#  'so soft , cooling and seamless',
#  'Thank you so much for arranging delivery promptly',
#  'Material is still nice',
#  'Material is quite good',
#  'thin material',
#  'given the price , reasonable buy',
#  'Size fits ok',
#  'Order well received',
#  'Delivery was quite fast',
#  'Item came in as stated',
#  'Received product as pictured',
#  'thin material',
#  'given the price , reasonable buy',
#  'Item looks good',
#  'soft and thin',
#  'small hole on the pants',
#  'Material is not too thin',
#  'Size fits ok',
#  'Order well received',
#  'Delivery was quite fast',
#  'Item came in as stated',
#  'Item looks good',
#  'delivery was nt great',
#  'turtle neck is quite cute',
#  'delivery was fast',
#  'Nice material',
#  'sizes fit perfectly',
#  "it 's so short",
#  'Item is in good condition',
#  'material is soft',
#  'fits nicely for me',
#  'Nice colours',
#  'Fits me well',
#  'material is extremely thin like almost see through',
#  'material is drifit ish and not cotton as i expected',
#  'there isint any defects',
#  'Prompt delivery',
#  'material is good and quite soft',
#  'Item was delivered promptly and as described',
#  'Material is ok',
#  'Items received in well packed',
#  'material is soft',
#  'fits nicely for me',
#  'Fast on delivery',
#  'material is very soft and not so thin',
#  'color is a bit different from the listing',
#  'sizes is same as local sizes',
#  'LOOKKS SO LEGIT',
#  'IT IS SO COMFORTABLE.man',
#  'Nice colours',
#  'Fits me well',
#  'it is the perfect size.so',
#  'Order well received in good condition',
#  'delivery time is relatively fast',
#  'I bought Size S and Size L. They are almost the same size with probably a difference of less than 1 cm',
#  'disappointed about the extremely fragile strings',
#  'Delivery takes a while',
#  'they fit my bras well',
#  'Size is a bit bigger than expected',
#  'Material is light and comfy',
#  'fabric is in good shape',
#  'Received the item with thanks',
#  'Soft Lycra material',
#  'wrinkled looked due to packaging',
#  'worth buying',
#  'nice and sleek',
#  'Quality feels good',
#  "it 's so cheap",
#  'should size up by 1 size',
#  'the bra is extremely comfortable',
#  'good Quality',
#  'Material is silky smooth',
#  'Received fast and in good condition',
#  'Fits perfectly',
#  'Pretty big for a medium',
#  'Material is comfy',
#  'Delivery is prompt',
#  'Quality looks good not too thick or thin',
#  'fitting also just nice',
#  'Fit my body well',
#  'Quite figure hugging',
#  'Seems comfy to wear',
#  'The size just nice for me',
#  'Love the colours',
#  'Items received in a well packed package',
#  'condition very good',
#  'very soft and smooth',
#  'Quality acceptable',
#  'delivery take about 5days , consider a little bit late',
#  'Items received as per description',
#  'Can fit OBC bras perfectly',
#  'just my size',
#  'Fit my body well',
#  'Quite figure hugging',
#  'Seems comfy to wear',
#  'The size just nice for me',
#  'cute',
#  'material is thick enough',
#  'Very cute',
#  'it fit perfectly',
#  'Love the colours',
#  'slightly long',
#  'thin & cooling material',
#  'can be quite sheer though',
#  'has some loose threads',
#  'Delivery took about 12 days to receive the item',
#  'good material',
#  'Nice colour',
#  'Items received in a well packed package',
#  'condition very good',
#  'very soft and smooth',
#  'Quality acceptable',
#  'Thank you for the quick delivery',
#  'stocking is very short',
#  'Look sexy',
#  'purchase come as described',
#  'Received in about a week',
#  'pant is very very THIN',
#  'cheap price',
#  'Size too small for me',
#  'The parcel is well - packaged',
#  'the size smaller than expected',
#  'quick delivery to doorstep',
#  'decent quality',
#  'Material feels ok',
#  'Buttons are cute',
#  'Items arrived in good condition',
#  'arrived less than a week',
#  'fast',
#  'So comfortable',
#  'delivery take about 5days , consider a little bit late',
#  'Nice colour',
#  'super cute',
#  'Material not too hot',
#  'sizing is same as indicated',
#  'Items received in good conditions',
#  'Delivery super quick',
#  'fitting for me but not tight',
#  'cutting is small',
#  'super soft',
#  'can be a little see thru',
#  'Quality of the pants still okay only',
#  'the size very big 😨',
#  'Love the material , so soft',
#  'Thank you for the quick delivery',
#  'stocking is very short',
#  'Look sexy',
#  'received very fast',
#  'delivery time was acceptable',
#  'Good condition nipple sticker',
#  'Bigger than i thought',
#  'Fits me perfectly',
#  'Super cuteee',
#  'Delivery took quite some time',
#  'Delivery took 2 weeks to arrive',
#  'They fit just nice',
#  'Material and workmanship so - so only',
#  'given the affordable price I would not complain',
#  'material is quite sheer',
#  'note.size is alright',
#  'Very Fast Delivery',
#  'Quality Very Good',
#  'abit thin and translucent',
#  'Received the items in good condition',
#  'quality ok with this price range',
#  'quality not that great',
#  'Quality worth the price 😊',
#  'Cooling To wear',
#  'not so smooth',
#  'Item received pretty fast',
#  'material seems to be a little thin',
#  'feels a little small',
#  'price quite ok',
#  'Item took 7 days to arrive',
#  'delivery is fast',
#  'very cute',
#  'Prices are very reasonable',
#  'delivery took a while',
#  'Delivery took slightly more than a week',
#  'decent for the price paid',
#  'Quality seems ok',
#  'size runs slightly small',
#  'Item took 7 days to arrive',
#  'delivery is fast',
#  'very cute',
#  'Prices are very reasonable',
#  'delivery took a while',
#  'worth getting during flash sale',
#  'Quite a fast delivery',
#  'Look nice',
#  'Thin but cooling',
#  'fits me',
#  'cup size is abit loose',
#  'next day received alrdy',
#  'material r very nice',
#  'cutting very nice',
#  'Delivery took slightly more than a week',
#  'decent for the price paid',
#  'definitely worth the price',
#  'material very rough',
#  'Quality seems ok',
#  'size runs slightly small',
#  'Value for money costume',
#  'true fit for sizing',
#  'material is good',
#  'cutting also nice',
#  'Item came quite fast',
#  'Delivery ok',
#  'feels comfortable',
#  'sleeve is just nice',
#  'Item received in good cobdition',
#  'Item come in good condition',
#  'Delivery took about 1 week to arrive',
#  'Fits well',
#  'received the item in good condition',
#  'I ordered 2 size too small',
#  'Item received on time',
#  'Size is not correct',
#  'the size is need to beware have to buy 1 to 2 size bigger',
#  'Received items in good condition',
#  'Feels just nice',
#  'Items took just under 2 weeks to arrive',
#  'Very cute socks',
#  'is value for money',
#  'Its comfortable',
#  'the size is need to beware have to buy 1 to 2 size bigger',
#  'Received items in good condition',
#  'acceptable for the price point',
#  'Polo t is standard quality',
#  'Feels just nice',
#  'breathable , comfy',
#  'Received promptly',
#  'ordered too big',
#  'there ’s loose treads',
#  'Items took just under 2 weeks to arrive',
#  'Very cute socks',
#  'Luckily I bought 1 size up',
#  'item received without damage',
#  'is value for money',
#  'Its comfortable',
#  'material fairly thin',
#  'Received in good order',
#  'Fast n acceptable delivery',
#  'Colors are different from pictures',
#  'material is very nice',
#  'color is very satisfying',
#  'design is pretty',
#  'very casual',
#  'Items came with no defect',
#  'fit nicely',
#  'Very nice material',
#  'design is pretty',
#  'acceptable for the price point',
#  'color is very satisfying',
#  'abit see through',
#  'Too cute',
#  'Items are received in good condition',
#  'Good Quality',
#  'nice colours',
#  'quality is amazing',
#  'measurements are accurate',
#  'fit nicely',
#  'took only 5 days to arrive',
#  'Ok delivery time',
#  'quality is quite decent also',
#  'Quite a good buy',
#  'Size is exactly',
#  'Cloth quality superb',
#  'pants quality is better than crocodile',
#  'such low price',
#  'Sewing quality is so neat',
#  'delivery reliable',
#  'well received',
#  'order well received',
#  'they look nice',
#  'delivery took some time to come',
#  'product was slightly thin',
#  'decent for price',
#  'Very comfy',
#  'Delivery was reasonable fast',
#  'For the price is is worth every cent',
#  'Feels like a comfy material',
#  'a little to snug for M size',
#  'Colour are nice',
#  'affordable pricing',
#  'sleeves are slightly long',
#  'strong chemical smell',
#  'Material is alright',
#  'Item arrived in a week',
#  'Delivery was a bit slow',
#  'is so comfortable',
#  "it 's just nice for my body",
#  'material seems good',
#  'cheaper than the shops',
#  'Look like pic',
#  'Item received comes with box and intact',
#  'Correct size delivered',
#  'received well packed',
#  'Good materials',
#  'Mask abit tight',
#  'Cape material not bad',
#  'Nice materiallll',
#  'Thick material',
#  'Quality is considered good for the price paid',
#  'well packed',
#  'Good for casual wear',
#  'Material is soft and light',
#  'Nice packaging',
#  'Quality was not bad',
#  'super cheap',
#  'fits perfectly',
#  'Received all items in good condition',
#  'Good very comfortbale',
#  'bought the wrong size',
#  'very cute vest',
#  'material is surprisingly good',
#  'received very quickly',
#  'items received in good condition',
#  'bloody comfortable',
#  ...]

# %%
len(X_test)
# Out:
# 272

# %%
#Vectorizer the sentences using Tfidf vale
#Make sure test data should be transformed using vectorizer learned from trainning data 
vectorizer = TfidfVectorizer(ngram_range=(1, 2), min_df=1)#unigram and bigram
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)

# same feature set

test_vectors.shape
# Out:
# (272, 2160)

# %%
train_vectors.shape
# Out:
# (1086, 2160)

# %%
#########################################################
#Apply NB model
clf_NB = MultinomialNB().fit(train_vectors, Y_train)
predNB = clf_NB.predict(test_vectors)
pred = list(predNB)



'''
errors=[]
for a,b, index in pred,Y_test:
    if a==b:
        continue
    else:
        errors.append(test_set[index])
print (errors)    
'''

print(metrics.confusion_matrix(Y_test, pred))
print(metrics.classification_report(Y_test, pred))
# Out:
# [[ 49  52]
#  [  6 165]]
#               precision    recall  f1-score   support
#
#           -1       0.89      0.49      0.63       101
#            1       0.76      0.96      0.85       171
#
#     accuracy                           0.79       272
#    macro avg       0.83      0.73      0.74       272
# weighted avg       0.81      0.79      0.77       272

# %%
#########################################################
# MaxEnt = LogisticRegression
clf_ME = LogisticRegression(random_state=0, solver='lbfgs').fit(train_vectors, Y_train)
predME = clf_ME.predict(test_vectors)
pred = list(predME)
print(metrics.confusion_matrix(Y_test, pred))
print(metrics.classification_report(Y_test, pred))
# Out:
# [[ 49  52]
#  [  8 163]]
#               precision    recall  f1-score   support
#
#           -1       0.86      0.49      0.62       101
#            1       0.76      0.95      0.84       171
#
#     accuracy                           0.78       272
#    macro avg       0.81      0.72      0.73       272
# weighted avg       0.80      0.78      0.76       272

# %%
filename = 'logreg_model_shopee_aspect.sav'
pk.dump(clf_ME, open(filename, 'wb'))
with open('vectorizer_shopee_aspect.pk', 'wb') as fin:
    pk.dump(vectorizer, fin)

# %%
vectorizer2 = pk.load(open('vectorizer_shopee_aspect.pk', 'rb'))
loaded_model = pk.load(open(filename, 'rb'))
predME = loaded_model.predict(test_vectors)
pred = list(predME)
print(metrics.confusion_matrix(Y_test, pred))
print(metrics.classification_report(Y_test, pred))
# Out:
# [[ 49  52]
#  [  8 163]]
#               precision    recall  f1-score   support
#
#           -1       0.86      0.49      0.62       101
#            1       0.76      0.95      0.84       171
#
#     accuracy                           0.78       272
#    macro avg       0.81      0.72      0.73       272
# weighted avg       0.80      0.78      0.76       272

# %%
test_vectors2 = vectorizer2.transform(["this shirt is not pretty"])
predME = loaded_model.predict(test_vectors2)
pred = list(predME)
pred
# Out:
# [1]

# %%
#####KNN Classifier
def train_knn(X, y, k, weight):
    """
    Create and train the k-nearest neighbor.
    """
    knn = KNeighborsClassifier(n_neighbors = k, weights = weight, metric = 'cosine', algorithm = 'brute')
    knn.fit(X, y)
    return knn


kn = train_knn(train_vectors, Y_train, 3, 'distance')# distance weights - by inverse of distance
predKN = kn.predict(test_vectors)
pred = list(predKN)
print(metrics.confusion_matrix(Y_test, pred))
print(metrics.classification_report(Y_test, pred))
# Out:
# [[ 64  37]
#  [ 19 152]]
#               precision    recall  f1-score   support
#
#           -1       0.77      0.63      0.70       101
#            1       0.80      0.89      0.84       171
#
#     accuracy                           0.79       272
#    macro avg       0.79      0.76      0.77       272
# weighted avg       0.79      0.79      0.79       272

# %%
#Apply SVM model
'''
Not all the feature points are needed to define the support vector.
In a way only the most informative feature points help to define the support vector which makes the SVM ideal for high-dimensional classification 
and sparse matrics common in NLP. 
The SVM can also work on feature points that are not linearly separable through kernel transformation of the feature points.
0.85 ACC
0.85 F1
'''

from sklearn import svm
from sklearn.svm import *

model_svm = LinearSVC(C=10)
clr_svm = model_svm.fit(train_vectors, Y_train)
#svm_clf=SVC(kernel="rbf",C=100) 
#clr_svm=svm_clf.fit(train_vectors,Y_train)

predicted = clr_svm.predict(test_vectors)
 
print(metrics.confusion_matrix(Y_test, predicted))
print(np.mean(predicted == Y_test) )
print(metrics.classification_report(Y_test, predicted))
# Out:
# [[ 71  30]
#  [ 20 151]]
# 0.8161764705882353
#               precision    recall  f1-score   support
#
#           -1       0.78      0.70      0.74       101
#            1       0.83      0.88      0.86       171
#
#     accuracy                           0.82       272
#    macro avg       0.81      0.79      0.80       272
# weighted avg       0.81      0.82      0.81       272

# %%
print(train_vectors)
# Out:
#   (0, 1207)	0.3358270464637099
#   (0, 625)	0.3840451279941372
#   (0, 1139)	0.3840451279941372
#   (0, 337)	0.3840451279941372
#   (0, 1062)	0.2305029146412067
#   (0, 1205)	0.27142815920639196
#   (0, 622)	0.31109398682857203
#   (0, 1138)	0.27142815920639196
#   (0, 336)	0.3840451279941372
#   (1, 1792)	0.5093768952050937
#   (1, 956)	0.601502800372808
#   (1, 1036)	0.26111540765003216
#   (1, 1766)	0.2910019709106944
#   (1, 946)	0.4752537812461231
#   (2, 1274)	0.6867184143585835
#   (2, 596)	0.4096572693305066
#   (2, 1273)	0.6004987436002724
#   (3, 1126)	0.8106551345509081
#   (3, 1115)	0.4584606476568686
#   (3, 1036)	0.3642143426284769
#   (4, 1573)	0.357855925892757
#   (4, 283)	0.4257102844960429
#   (4, 1089)	0.45075330934700836
#   (4, 219)	0.340087616991402
#   (4, 1568)	0.22214720868618526
#   :	:
#   (1084, 949)	0.25462382050107685
#   (1084, 2083)	0.25462382050107685
#   (1084, 1765)	0.25462382050107685
#   (1084, 1853)	0.25462382050107685
#   (1084, 730)	0.25462382050107685
#   (1084, 403)	0.25462382050107685
#   (1084, 2081)	0.24047738933300902
#   (1084, 1762)	0.23044033668693878
#   (1084, 1913)	0.19211042170473291
#   (1084, 2058)	0.18673219818295597
#   (1084, 1054)	0.1984715100007759
#   (1084, 181)	0.22265499381491397
#   (1084, 1885)	0.13481409421677337
#   (1084, 2012)	0.21629390551887098
#   (1084, 1842)	0.1547633714967931
#   (1084, 1977)	0.11295743192188087
#   (1084, 1036)	0.10003531557247401
#   (1084, 946)	0.18207336905866267
#   (1085, 357)	0.4652829681146807
#   (1085, 1574)	0.4652829681146807
#   (1085, 356)	0.4394327021452374
#   (1085, 2009)	0.4394327021452374
#   (1085, 1630)	0.29263230950752434
#   (1085, 1977)	0.20641104627130688
#   (1085, 1568)	0.22930793955930312

# %%
###############################################
##Select K Best features

ch21 = SelectKBest(chi2, k=200)
# Transform your training and testing datasets accordingly
train_Kbest = ch21.fit_transform(train_vectors, Y_train)
test_Kbest = ch21.transform(test_vectors)
train_Kbest.shape
# Out:
# (1086, 200)

# %%
#Re-Train ME model
clf_ME = LogisticRegression(random_state=0, solver='lbfgs').fit(train_Kbest, Y_train)
predME = clf_ME.predict(test_Kbest)
pred = list(predME)
print(metrics.confusion_matrix(Y_test, pred))
print(metrics.classification_report(Y_test, pred))
# Out:
# [[ 44  57]
#  [  6 165]]
#               precision    recall  f1-score   support
#
#           -1       0.88      0.44      0.58       101
#            1       0.74      0.96      0.84       171
#
#     accuracy                           0.77       272
#    macro avg       0.81      0.70      0.71       272
# weighted avg       0.79      0.77      0.74       272

# %%
train_vectors.shape
# Out:
# (1086, 2160)
